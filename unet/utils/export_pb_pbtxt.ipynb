# %% [markdown]
# [Code reference](https://medium.com/@sebastingarcaacosta/how-to-export-a-tensorflow-2-x-keras-model-to-a-frozen-and-optimized-graph-39740846d9eb)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
print(f"TF version: {tf.__version__}")
from tensorflow import keras
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
import numpy as np
# Out:
# TF version: 2.8.2

# %%
from keras.models import load_model

MODEL_DIR = "/content/drive/MyDrive/Uni/CV Project/Alberto/models/saved_models/simple_model"

# path of the directory where you want to save your model
frozen_out_path = MODEL_DIR

# name of the .pb file
frozen_graph_filename = "frozen_unet"

model = load_model(MODEL_DIR)

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 384, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 390, 230, 3)  0           ['input_13[0][0]']
#
#  conv1_conv (Conv2D)            (None, 192, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 192, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 192, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 194, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 96, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 96, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 96, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 96, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 96, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 96, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 96, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 96, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 96, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 96, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 96, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 96, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 96, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 96, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 96, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 96, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 96, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 96, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 96, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 96, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 96, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 96, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 96, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 96, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 96, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 96, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 96, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 96, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 96, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 96, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 96, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 96, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 96, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 48, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 48, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 48, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 48, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 48, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 48, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 48, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 48, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 48, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 48, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 48, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 48, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 48, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 48, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 48, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 48, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 48, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 48, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 48, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 48, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 48, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 48, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 48, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 48, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 48, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 48, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 48, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 48, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 48, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 48, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 48, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 48, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 48, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 48, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 48, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 48, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 48, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 48, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 48, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 48, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 48, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 48, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 24, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 24, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 24, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 24, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 24, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 24, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 24, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 24, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 24, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 24, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 24, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 24, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 24, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 24, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 24, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 24, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 24, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 24, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 24, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 24, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 24, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 24, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 24, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 24, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 24, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 24, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 24, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 24, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 24, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 24, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 24, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 24, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 24, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 24, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 24, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 24, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 256)   0           ['conv4_block6_2_relu[0][0]']
#  oling2D)
#
#  conv2d_73 (Conv2D)             (None, 1, 1, 256)    65792       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_73[0][0]']
#  ormalization)
#
#  conv2d_74 (Conv2D)             (None, 24, 14, 256)  65536       ['conv4_block6_2_relu[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 24, 14, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 24, 14, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 24, 14, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  tf.nn.relu_15 (TFOpLambda)     (None, 1, 1, 256)    0           ['batch_normalization_69[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 24, 14, 256)  1024       ['conv2d_74[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (None, 24, 14, 256)  1024       ['conv2d_75[0][0]']
#  ormalization)
#
#  batch_normalization_72 (BatchN  (None, 24, 14, 256)  1024       ['conv2d_76[0][0]']
#  ormalization)
#
#  batch_normalization_73 (BatchN  (None, 24, 14, 256)  1024       ['conv2d_77[0][0]']
#  ormalization)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 24, 14, 256)  0          ['tf.nn.relu_15[0][0]']
#
#  tf.nn.relu_16 (TFOpLambda)     (None, 24, 14, 256)  0           ['batch_normalization_70[0][0]']
#
#  tf.nn.relu_17 (TFOpLambda)     (None, 24, 14, 256)  0           ['batch_normalization_71[0][0]']
#
#  tf.nn.relu_18 (TFOpLambda)     (None, 24, 14, 256)  0           ['batch_normalization_72[0][0]']
#
#  tf.nn.relu_19 (TFOpLambda)     (None, 24, 14, 256)  0           ['batch_normalization_73[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 24, 14, 1280  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'tf.nn.relu_16[0][0]',
#                                                                   'tf.nn.relu_17[0][0]',
#                                                                   'tf.nn.relu_18[0][0]',
#                                                                   'tf.nn.relu_19[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 24, 14, 256)  327680      ['concatenate_28[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 24, 14, 256)  1024       ['conv2d_78[0][0]']
#  ormalization)
#
#  conv2d_79 (Conv2D)             (None, 96, 56, 48)   3072        ['conv2_block3_2_relu[0][0]']
#
#  tf.nn.relu_20 (TFOpLambda)     (None, 24, 14, 256)  0           ['batch_normalization_74[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 96, 56, 48)  192         ['conv2d_79[0][0]']
#  ormalization)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 96, 56, 256)  0          ['tf.nn.relu_20[0][0]']
#
#  tf.nn.relu_21 (TFOpLambda)     (None, 96, 56, 48)   0           ['batch_normalization_75[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 96, 56, 304)  0           ['up_sampling2d_5[0][0]',
#                                                                   'tf.nn.relu_21[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 96, 56, 256)  700416      ['concatenate_29[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 96, 56, 256)  1024       ['conv2d_80[0][0]']
#  ormalization)
#
#  tf.nn.relu_22 (TFOpLambda)     (None, 96, 56, 256)  0           ['batch_normalization_76[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 96, 56, 256)  589824      ['tf.nn.relu_22[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 96, 56, 256)  1024       ['conv2d_81[0][0]']
#  ormalization)
#
#  tf.nn.relu_23 (TFOpLambda)     (None, 96, 56, 256)  0           ['batch_normalization_77[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 384, 224, 25  0          ['tf.nn.relu_23[0][0]']
#                                 6)
#
#  conv2d_82 (Conv2D)             (None, 384, 224, 1)  257         ['up_sampling2d_6[0][0]']
#
# ==================================================================================================
# Total params: 11,852,353
# Trainable params: 11,819,617
# Non-trainable params: 32,736
# __________________________________________________________________________________________________

# %% [markdown]
# Convert the Keras model to ConcreteFunction format, which is more general

# %%
# Convert Keras model to ConcreteFunction
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))

# %% [markdown]
# Once we have our model in the format of ConcreteFunction, we convert its variables to constants

# %%
# Get frozen graph def
frozen_func = convert_variables_to_constants_v2(full_model)
# frozen_func.graph.as_graph_def()

# %% [markdown]
# We are almost done. If you want to inspect the layers operations inside your frozen graph definition and see the name of its input and output tensors (important for the next stage), use this code

# %%
# layers = [op.name for op in frozen_func.graph.get_operations()]
# print("-" * 60)
# print("Frozen model layers: ")
# for layer in layers:
#     print(layer)
# print("-" * 60)
# print("Frozen model inputs: ")
# print(frozen_func.inputs)
# print("Frozen model outputs: ")
# print(frozen_func.outputs)

# %% [markdown]
# Then, serialize the frozen graph and its text representation to disk

# %%
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                  logdir=frozen_out_path,
                  name=f"{frozen_graph_filename}.pb",
                  as_text=False)
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                  logdir=frozen_out_path,
                  name=f"{frozen_graph_filename}.pbtxt",
                  as_text=True)
# Out:
# '/content/drive/MyDrive/Uni/CV Project/Alberto/models/saved_models/simple_model/frozen_unet.pbtxt'

# %%
# !pip uninstall -y tensorflow
# !pip install tensorflow-gpu==1.13.1
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
# Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.13.1
#   Downloading tensorflow_gpu-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (345.0 MB)
#      |████████████████████████████████| 345.0 MB 3.9 kB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.21.6)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.5.3)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (3.17.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.47.0)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading tensorboard-1.13.1-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 52.8 MB/s
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367 kB)
#      |████████████████████████████████| 367 kB 68.4 MB/s
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.2 MB/s
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.15.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.37.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.4.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (4.1.1)
# Collecting mock>=2.0.0
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (1.5.2)
# Installing collected packages: mock, tensorflow-estimator, tensorboard, keras-applications, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# Successfully installed keras-applications-1.0.8 mock-4.0.3 tensorboard-1.13.1 tensorflow-estimator-1.13.0 tensorflow-gpu-1.13.1

# %% [markdown]
# In this stage, we’ll use a helper function in order to optimize the graph for inference available in TensorFlow 1.x

# %%
import tensorflow as tf
print(f"TF version: {tf.__version__}")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# TF version: 1.13.1

# %%
# !python -m tensorflow.python.tools.optimize_for_inference --input "/content/drive/MyDrive/Uni/CV Project/Alberto/models/saved_models/simple_model/frozen_unet.pb" \
--output "/content/drive/MyDrive/Uni/CV Project/Alberto/models/saved_models/simple_model/optimized_unet.pb" --frozen_graph=True --input_names=x --output_names=Identity
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/tools/strip_unused_lib.py:86: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/tools/optimize_for_inference.py:95: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.

# %%
# Needs tensorflow 1.5
import tensorflow as tf

MODEL_DIR = "/content/drive/MyDrive/Uni/CV Project/Alberto/models/saved_models/simple_model"

optimized_graph_path = MODEL_DIR + "/optimized_unet.pb"
output_pbtxt = MODEL_DIR + "/optimized_unet.pbtxt"

# Read the graph.
with tf.gfile.FastGFile(optimized_graph_path, "rb") as f:
  graph_def = tf.GraphDef()
  graph_def.ParseFromString(f.read())

# Remove Const nodes.
for i in reversed(range(len(graph_def.node))):
  if graph_def.node[i].op == 'Const' or graph_def.node[i].op == 'Mul' or graph_def.node[i].op == 'ResizeBilinear' \
  or graph_def.node[i].op == 'ConcatV2' or graph_def.node[i].op == 'Conv2D' or graph_def.node[i].op == 'FusedBatchNormV3':
      del graph_def.node[i]
  print(graph_def.node[i].op)
  for attr in ['T', 'data_format', 'Tshape', 'N', 'Tidx', 'Tdim',
                'use_cudnn_on_gpu', 'Index', 'Tperm', 'is_training',
                'Tpaddings']:
      if attr in graph_def.node[i].attr:
          del graph_def.node[i].attr[attr]

# Save as text.
tf.train.write_graph(graph_def, "", output_pbtxt, as_text=True)
# Out:
# FusedResizeAndPadConv2D
# FusedResizeAndPadConv2D
# Identity
# NoOp
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# SpaceToBatchND
# SpaceToBatchND
# SpaceToBatchND
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# SpaceToBatchND
# SpaceToBatchND
# SpaceToBatchND
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# BatchToSpaceND
# SpaceToBatchND
# SpaceToBatchND
# SpaceToBatchND
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# AvgPool
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# AddV2
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# MaxPool
# Pad
# Pad
# Relu
# Relu
# Relu
# Relu
# Relu
# Relu
# BiasAdd
# BiasAdd
# BiasAdd
# BiasAdd
# Pad
# Pad
# Placeholder
# '/content/drive/MyDrive/Uni/CV Project/Alberto/models/saved_models/simple_model/optimized_unet.pbtxt'
